# %% [markdown]
# $$\Large{\text{Adaptive Neuro Fuzzy Inference System}}$$

# %% [markdown]
# **Foi utilizado o Pacote "ANFIS" do R**

# %% [markdown]
# **Passos**
# * Criar as funções de Pertinência Fuzzy
#
# * Definir o conjunto de regras ( Tipo 3-Takagi-Sugeno )
#
# *  Construir todas as combinações de Regras - Por exemplo, duas entras e duas funções de pertinências geram 4 regras fuzzy
#
# * Aplicar o método de aprendizagem Híbrido
#
# * Gerar os múltiplos outpus

# %% [markdown]
# -----------------------------------------------------------
# * Layer 1: The fuzzification process which transforms crisp values into linguistic terms using the Gaussian function as the shape of the membership function.
# * Layer 2: The inference stage using the t-norm operator (the AND operator).
# * Layer 3: Calculating the ratio of the strengths of the rules.
# * Layer 4: Calculating the consequent parameters.
# * Layer 5: Calculating the overall output as the sum of all incoming signals.

# %% [markdown]
# ## Exemplo
# [Link para o CRAN R-PROJECT](https://cran.r-project.org/web/packages/anfis/index.html)

# %%
#instalar o pacote 
install.packages('anfis')
# Out:
# Installing package into ‘/home/arnaldonot/R/i686-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)

# %%
#carregar o pacote
library(anfis)
# Out:
# Loading required package: parallel

# %%
#Como geralmente há muitas operações ele sempre set a possibilidade de usar multiplos CORES 
##Set 4 cores using global options for multicore
options(cores=4)

# %%
##Example domain for bidimentional sinc(x,y) function
x <- seq(-10, 10, length= 11)

# %%
x
# Out:
#  [1] -10  -8  -6  -4  -2   0   2   4   6   8  10

# %%
trainingSet <- trainSet(x,x)

# %%
#sumário da função.
trainSet
# Out:
# function (x, y)
# {
#     sinc <- function(z) {
#         ifelse(z == 0, 1, sin(z)/z)
#     }
#     out <- matrix(ncol = 3, nrow = 0)
#     colnames(out) <- c("x", "y", "z")
#     invisible(sapply(x, function(X) {
#         sapply(y, function(Y) {
#             out <<- rbind(out, c(X, Y, sinc(X) * sinc(Y)))
#             return(NULL)
#         })
#     }))
#     return(out)
# }
# <bytecode: 0xaa81a48>
# <environment: namespace:anfis>

# %%
trainingSet
# Out:
#       x   y   z
#  [1,] -10 -10  0.002959590
#  [2,] -10  -8 -0.006727897
#  [3,] -10  -6  0.002533465
#  [4,] -10  -4  0.010292913
#  [5,] -10  -2 -0.024733850
#  [6,] -10   0 -0.054402111
#  [7,] -10   2 -0.024733850
#  [8,] -10   4  0.010292913
#  [9,] -10   6  0.002533465
# [10,] -10   8 -0.006727897
# [11,] -10  10  0.002959590
# [12,]  -8 -10 -0.006727897
# [13,]  -8  -8  0.015294215
# [14,]  -8  -6 -0.005759209
# [15,]  -8  -4 -0.023398400
# [16,]  -8  -2  0.056226307
# [17,]  -8   0  0.123669781
# [18,]  -8   2  0.056226307
# [19,]  -8   4 -0.023398400
# [20,]  -8   6 -0.005759209
# [21,]  -8   8  0.015294215
# [22,]  -8  10 -0.006727897
# [23,]  -6 -10  0.002533465
# [24,]  -6  -8 -0.005759209
# [25,]  -6  -6  0.002168695
# [26,]  -6  -4  0.008810931
# [27,]  -6  -2 -0.021172649
# [28,]  -6   0 -0.046569250
# [29,]  -6   2 -0.021172649
# [30,]  -6   4  0.008810931
# [31,] ⋮   ⋮   ⋮
# [32,]  6   -4  0.008810931
new(Class="NormalizedGaussianMF",parameters=c(mu=-5,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=0,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=5,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=10,sigma=2))),
y=c(new(Class="NormalizedGaussianMF",parameters=c(mu=-10,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=-5,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=0,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=5,sigma=2)),
new(Class="NormalizedGaussianMF",parameters=c(mu=10,sigma=2))))

# %%
membershipFunction
# Out:
# $x
# $x[[1]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#   -10     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $x[[2]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#    -5     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $x[[3]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#     0     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $x[[4]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#     5     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $x[[5]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#    10     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
#
# $y
# $y[[1]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#   -10     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $y[[2]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#    -5     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $y[[3]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#     0     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $y[[4]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#     5     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))
#
# $y[[5]]
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#    mu sigma
#    10     2
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))

# %% [markdown]
# ELE CRIA DUAS ENTRADAS X E Y.....DEPOIS CRIAS AS 5 REPRESENTAÇÕES FUZZY PARA CADA UMA DAS ESTRADAS.OU SEJA, CADA ENTRADA É AVALIADA SOBRE 5 ASPECTOS FUZZY....PASSADO  O PRIMEIRO NÍVEL DA REDE NEURAL É NOVAMENTE AVALIADA SOBRE OS 5 CONJUNTOS FUZZY NOVAMENTE

# %%
#
##Creating the ANFIS network with 2 inputs and 4 MembershipFunctions in each input
anfis3 <- new(Class="ANFIS",X,Y,membershipFunction)
anfis3
# Out:
# ANFIS network
# Trainning Set:
# 	 dim(x)= 121x2
# 	 dim(y)= 121x1
# Arquitecture:  2 ( 5x5 ) - 25 - 75 ( 75x1 ) - 1
# Network not trained yet

# %%
##Check for epsilon-completeness in each input
## Not run: plotMFs(anfis3)
plotMFs(anfis3)
# Out:
# plot without title

# %%
#
##Check for epsilon-completeness in each input
## Not run: plotMFs(anfis3)
#
##Training the ANFIS network
trainOutput <- trainHybridJangOffLine(anfis3, epochs=10)
# Out:
# [1] "epoch:  1"
# [1] "epoch:  2"
# [1] "epoch:  3"
# [1] "epoch:  4"
# [1] "epoch:  5"
# [1] "epoch:  6"
# [1] "epoch:  7"
# [1] "epoch:  8"
# [1] "epoch:  9"

# %%
##How the training went
## Not run: plot(anfis3)
#
plot(anfis3)
#
# Out:
# Plot with title “Training Hybrid Off-Line Jang Error”

# %%
##Test the fit
##MembershipFunctions
## Not run: plotMFs(anfis3)
#
plotMFs(anfis3)
# Out:
# plot without title

# %%
##Just to see if premises, consequents and errors were updated
getPremises(anfis3)[[1]][[1]]
# Out:
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#        mu     sigma
# -9.989877  2.024529
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))

# %% [markdown]
# Realmente a rede aprendeu e ajustou os novos conjuntos fuzzy de acordo com a aprendizagem. Antes tínhamos mu= -10 e sigma = 2

# %%
getConsequents(anfis3)[1:2,]
# Out:
# [1] 0.004736946 0.004736946

# %%
getErrors(anfis3) #Training errors
# Out:
# [1] 0.03741022 0.03238312 0.02992609 0.02866609 0.02759035 0.02661405 0.02569998
# [8] 0.02482807 0.02398628

# %%
getTrainingType(anfis3)
# Out:
# [1] "trainHybridJangOffLine"

# %%
names(coef(anfis3))
# Out:
# [1] "premises"    "consequents"

# %%
coef(anfis3)$premises[[input=1]][[mf=1]] #legais isso
# Out:
# MembershipFunction:  Normalized Gaussian Membership Function
# Number of parameters: 2
#        mu     sigma
# -9.989877  2.024529
# Expression: expression(exp(-1/2 * ((x - mu)/sigma)^2))

# %%
coef(anfis3)$consequents[1:2,]
# Out:
# [1] 0.004736946 0.004736946

# %%
##First five train pattern associated values for the training process
fitted(anfis3)[1:5,]
# Out:
# [1] -0.008596328  0.008127665  0.013378351 -0.004183393 -0.030539780

# %%
resid(anfis3)[1:5,]
# Out:
# [1]  0.011555918 -0.014855562 -0.010844885  0.014476307  0.005805931

# %%
summary(anfis3)
# Out:
# ANFIS network
# Trainning Set:
# 	 dim(x)= 121x2
# 	 dim(y)= 121x1
# Arquitecture:  2 ( 5x5 ) - 25 - 75 ( 75x1 ) - 1
# Last training error:  0.02398628
#
# Call: trainHybridJangOffLine(object = anfis3, epochs = 10)
#
# Statistics for Off-line training
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.02399 0.02570 0.02759 0.02857 0.02993 0.03741

# %%
##Surface comparison between the original training set and the predicted ANFIS network
y <- predict(anfis3,X)

# %%
y
# Out:
#       z
#  [1,] -0.008596328
#  [2,]  0.008127665
#  [3,]  0.013378351
#  [4,] -0.004183393
#  [5,] -0.030539780
#  [6,] -0.039094482
#  [7,] -0.030539780
#  [8,] -0.004183393
#  [9,]  0.013378351
# [10,]  0.008127665
# [11,] -0.008596328
# [12,]  0.008127665
# [13,] -0.004386843
# [14,] -0.018553117
# [15,] -0.004895383
# [16,]  0.062538397
# [17,]  0.099708944
# [18,]  0.062538397
# [19,] -0.004895383
# [20,] -0.018553117
# [21,] -0.004386843
# [22,]  0.008127665
# [23,]  0.013378351
# [24,] -0.018553117
# [25,] -0.010579011
# [26,]  0.022107603
# [27,] -0.011499515
# [28,] -0.049330285
# [29,] -0.011499515
# [30,]  0.022107603
# [31,] ⋮
# [32,]  0.022107603
# [33,] -0.011499515
# [34,] -0.049330285
# [35,] -0.011499515
# [36,]  0.022107603
# [37,] -0.010579011
# [38,] -0.018553117
# [39,]  0.013378351
# [40,]  0.008127665
# [41,] -0.004386843
# [42,] -0.018553117
# [43,] -0.004895383
# [44,]  0.062538397
# [45,]  0.099708944
# [46,]  0.062538397
# [47,] -0.004895383
# [48,] -0.018553117
# [49,] -0.004386843
# [50,]  0.008127665
# [51,] -0.008596328
# [52,]  0.008127665
# [53,]  0.013378351
# [54,] -0.004183393
# [55,] -0.030539780
# [56,] -0.039094482
# [57,] -0.030539780
# [58,] -0.004183393
# [59,]  0.013378351
# [60,]  0.008127665
# [61,] -0.008596328

# %%
z <- matrix(y[,1],ncol=length(x),nrow=length(x))

# %%
z
# Out:
#       [,1]         [,2]         [,3]        [,4]         [,5]
#  [1,] -0.008596328  0.008127665  0.01337835 -0.004183393 -0.03053978
#  [2,]  0.008127665 -0.004386843 -0.01855312 -0.004895383  0.06253840
#  [3,]  0.013378351 -0.018553117 -0.01057901  0.022107603 -0.01149952
#  [4,] -0.004183393 -0.004895383  0.02210760  0.022476744 -0.10248094
#  [5,] -0.030539780  0.062538397 -0.01149952 -0.102480943  0.21368269
#  [6,] -0.039094482  0.099708944 -0.04933028 -0.183958603  0.46289749
#  [7,] -0.030539780  0.062538397 -0.01149952 -0.102480943  0.21368269
#  [8,] -0.004183393 -0.004895383  0.02210760  0.022476744 -0.10248094
#  [9,]  0.013378351 -0.018553117 -0.01057901  0.022107603 -0.01149952
# [10,]  0.008127665 -0.004386843 -0.01855312 -0.004895383  0.06253840
# [11,] -0.008596328  0.008127665  0.01337835 -0.004183393 -0.03053978
#       [,6]        [,7]        [,8]         [,9]        [,10]
#  [1,] -0.03909448 -0.03053978 -0.004183393  0.01337835  0.008127665
#  [2,]  0.09970894  0.06253840 -0.004895383 -0.01855312 -0.004386843
#  [3,] -0.04933028 -0.01149952  0.022107603 -0.01057901 -0.018553117
#  [4,] -0.18395860 -0.10248094  0.022476744  0.02210760 -0.004895383
#  [5,]  0.46289749  0.21368269 -0.102480943 -0.01149952  0.062538397
#  [6,]  0.94795554  0.46289749 -0.183958603 -0.04933028  0.099708944
#  [7,]  0.46289749  0.21368269 -0.102480943 -0.01149952  0.062538397
#  [8,] -0.18395860 -0.10248094  0.022476744  0.02210760 -0.004895383
#  [9,] -0.04933028 -0.01149952  0.022107603 -0.01057901 -0.018553117
# [10,]  0.09970894  0.06253840 -0.004895383 -0.01855312 -0.004386843
# [11,] -0.03909448 -0.03053978 -0.004183393  0.01337835  0.008127665
#       [,11]
#  [1,] -0.008596328
#  [2,]  0.008127665
#  [3,]  0.013378351
#  [4,] -0.004183393
#  [5,] -0.030539780
#  [6,] -0.039094482
#  [7,] -0.030539780
#  [8,] -0.004183393
#  [9,]  0.013378351
# [10,]  0.008127665
# [11,] -0.008596328

# %% [markdown]
# ### numeric matrix with the columns x, y and z=sync(x,y)

# %%
##Domain definition for a regular (x,y) grid with 11 points for each coordenates
x <- seq(-10, 10, length= 11)

# %%
x
# Out:
#  [1] -10  -8  -6  -4  -2   0   2   4   6   8  10

# %%
trainingSet <- trainSet(x,x)

# %%
trainingSet
# Out:
#       x   y   z
#  [1,] -10 -10  0.002959590
#  [2,] -10  -8 -0.006727897
#  [3,] -10  -6  0.002533465
#  [4,] -10  -4  0.010292913
#  [5,] -10  -2 -0.024733850
#  [6,] -10   0 -0.054402111
#  [7,] -10   2 -0.024733850
#  [8,] -10   4  0.010292913
#  [9,] -10   6  0.002533465
# [10,] -10   8 -0.006727897
# [11,] -10  10  0.002959590
# [12,]  -8 -10 -0.006727897
# [13,]  -8  -8  0.015294215
# [14,]  -8  -6 -0.005759209
# [15,]  -8  -4 -0.023398400
# [16,]  -8  -2  0.056226307
# [17,]  -8   0  0.123669781
# [18,]  -8   2  0.056226307
# [19,]  -8   4 -0.023398400
# [20,]  -8   6 -0.005759209
# [21,]  -8   8  0.015294215
# [22,]  -8  10 -0.006727897
# [23,]  -6 -10  0.002533465
# [24,]  -6  -8 -0.005759209
# [25,]  -6  -6  0.002168695
# [26,]  -6  -4  0.008810931
# [27,]  -6  -2 -0.021172649
# [28,]  -6   0 -0.046569250
# [29,]  -6   2 -0.021172649
# [30,]  -6   4  0.008810931
# [31,] ⋮   ⋮   ⋮
# [32,]  6   -4  0.008810931
# [33,]  6   -2 -0.021172649
# [34,]  6    0 -0.046569250
# [35,]  6    2 -0.021172649
# [36,]  6    4  0.008810931
# [37,]  6    6  0.002168695
# [38,]  6    8 -0.005759209
# [39,]  6   10  0.002533465
# [40,]  8  -10 -0.006727897
# [41,]  8   -8  0.015294215
# [42,]  8   -6 -0.005759209
# [43,]  8   -4 -0.023398400
# [44,]  8   -2  0.056226307
# [45,]  8    0  0.123669781
# [46,]  8    2  0.056226307
# [47,]  8    4 -0.023398400
# [48,]  8    6 -0.005759209
# [49,]  8    8  0.015294215
# [50,]  8   10 -0.006727897
# [51,] 10  -10  0.002959590
# [52,] 10   -8 -0.006727897
# [53,] 10   -6  0.002533465
# [54,] 10   -4  0.010292913
# [55,] 10   -2 -0.024733850
# [56,] 10    0 -0.054402111
# [57,] 10    2 -0.024733850
# [58,] 10    4  0.010292913
# [59,] 10    6  0.002533465
# [60,] 10    8 -0.006727897
# [61,] 10   10  0.002959590

# %%
Z <- matrix(trainingSet[,"z"],ncol=length(x),nrow=length(x))

# %%
Z
# Out:
#       [,1]         [,2]         [,3]         [,4]         [,5]
#  [1,]  0.002959590 -0.006727897  0.002533465  0.010292913 -0.02473385
#  [2,] -0.006727897  0.015294215 -0.005759209 -0.023398400  0.05622631
#  [3,]  0.002533465 -0.005759209  0.002168695  0.008810931 -0.02117265
#  [4,]  0.010292913 -0.023398400  0.008810931  0.035796876 -0.08601982
#  [5,] -0.024733850  0.056226307 -0.021172649 -0.086019820  0.20670545
#  [6,] -0.054402111  0.123669781 -0.046569250 -0.189200624  0.45464871
#  [7,] -0.024733850  0.056226307 -0.021172649 -0.086019820  0.20670545
#  [8,]  0.010292913 -0.023398400  0.008810931  0.035796876 -0.08601982
#  [9,]  0.002533465 -0.005759209  0.002168695  0.008810931 -0.02117265
# [10,] -0.006727897  0.015294215 -0.005759209 -0.023398400  0.05622631
# [11,]  0.002959590 -0.006727897  0.002533465  0.010292913 -0.02473385
#       [,6]        [,7]        [,8]         [,9]         [,10]
#  [1,] -0.05440211 -0.02473385  0.010292913  0.002533465 -0.006727897
#  [2,]  0.12366978  0.05622631 -0.023398400 -0.005759209  0.015294215
#  [3,] -0.04656925 -0.02117265  0.008810931  0.002168695 -0.005759209
#  [4,] -0.18920062 -0.08601982  0.035796876  0.008810931 -0.023398400
#  [5,]  0.45464871  0.20670545 -0.086019820 -0.021172649  0.056226307
#  [6,]  1.00000000  0.45464871 -0.189200624 -0.046569250  0.123669781
#  [7,]  0.45464871  0.20670545 -0.086019820 -0.021172649  0.056226307
#  [8,] -0.18920062 -0.08601982  0.035796876  0.008810931 -0.023398400
#  [9,] -0.04656925 -0.02117265  0.008810931  0.002168695 -0.005759209
# [10,]  0.12366978  0.05622631 -0.023398400 -0.005759209  0.015294215
# [11,] -0.05440211 -0.02473385  0.010292913  0.002533465 -0.006727897
#       [,11]
#  [1,]  0.002959590
#  [2,] -0.006727897
#  [3,]  0.002533465
#  [4,]  0.010292913
#  [5,] -0.024733850
#  [6,] -0.054402111
#  [7,] -0.024733850
#  [8,]  0.010292913
#  [9,]  0.002533465
# [10,] -0.006727897
# [11,]  0.002959590

# %%
##Ploting the domain
persp(x,x,Z,theta = 45, phi = 15, expand = 0.8, col = "lightblue",ticktype="detailed",main="sinc(x)*sinc(y)")
# Out:
# Plot with title “sinc(x)*sinc(y)”
